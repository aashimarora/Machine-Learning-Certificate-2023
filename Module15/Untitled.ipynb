# %%
"""
To access the file arena_ml__retailers.csv click 
"Files" in the top right menu bar next to the 
instructions.

You can install additional python packages using the 
coderpad shell in the bottom right hand corner of 
coderpad. Make sure to also update requirements.txt. 
To access the coderpad shell, click "Program Output" 
in the top right menu bar next to the instructions.
"""

import pandas as pd
import numpy as np 
import Levenshtein
from enum import Enum, auto
from dataclasses import dataclass



#implement HAC to group stores belonging to the same retailer using 
#retailer_nm_modified and any additional attributes 

#retailer_d and retailer_nm should not be used during clustering 
#since it is the ground truth for each record and will be used to evaluate 
#solution


#Define linkages

class Linkage(Enum):
  SINGLE = auto()
  COMPLETE = auto()
  AVERAGE = auto()
  CENTROID = auto()
  WARD = auto()

'''
class Cluster
'''
class Cluster:
  
  #Linkage will be shared by all class members
  linkage = Linkage.SINGLE

  def __init__(self, cluster_id: str):
    self.cluster_id = cluster_id

  def merge_cluster_with(self, c):
    pass

  @classmethod
  def get_distance_based_on_linkage(clusters: list):
    pass


'''
Class: HierarchicalClustering
Output: Assign a predicted cluster_id to each record
Linkage, scoring, threshold subjective
Needs to use the column retailer_nm_modified

'''
class HierarchicalClustering:

  def __init__(self):
    #add parameters
    self.linkage = Linkage.SINGLE
  
  def load_data(self, filepath: str):
    df = pd.read_csv(filepath)
    print(df.head())
    print(df.columns)
    return df 


  def accuracy(self):
    pass

  def getLevenshteinDistance(self, word1: str, word2: str):
      distance = Levenshtein.distance(word1, word2)
      return distance

  def hierarchical_clustering(self, df: pd.DataFrame):
    rows = len(df)
    #Initialize N clusters, here is number of rows in this data
    clusters = [Cluster(f'c{x}') for x in rows]
    #initialize distance matrix i.e the distance between each cluster
    distanceMat = np.zeros(rows,rows)

    
    pass

  def preprocess_data(self, df: pd.DataFrame):
    #check if data needs to be normalized and scaled 
    #we are only using retailer_nm_modified, no scaling 
    #required
    #make a copy and remove columns 
    df_copy = df.copy()
    cols = df.columns
    df_copy = df_copy.drop(columns=['retailer_id', 'retailer_nm'])
    print(df_copy.head)
    print(df_copy.columns)
    return df_copy

  

hac = HierarchicalClustering()
df = hac.load_data('/home/coderpad/data/arena_ml__retailers.csv')
#this is a copy, df has not been modified
preprocessed_df = hac.preprocess_data(df)
print(preprocessed_df['retailer_nm_modified']).unique()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ff2bde5fd791> in <module>
#     107
#     108 hac = HierarchicalClustering()
# --> 109 df = hac.load_data('/home/coderpad/data/arena_ml__retailers.csv')
#     110 #this is a copy, df has not been modified
#     111 preprocessed_df = hac.preprocess_data(df)
#
# <ipython-input-3-ff2bde5fd791> in load_data(self, filepath)
#      69
#      70   def load_data(self, filepath: str):
# ---> 71     df = pd.read_csv(filepath)
#      72     print(df.head())
#      73     print(df.columns)
#
# ...

# %%
pip install Levenshtein
# Out:
# ...
#      |████████████████████████████████| 135 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 17.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.4; however, version 24.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df,
